# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matpowercaseframes import CaseFrames

# %%
CASE_NAME = "case9.m"

# %%
cf = CaseFrames(CASE_NAME)
cf.infer_numpy()
cf.bus
# Out:
#    BUS_I  BUS_TYPE   PD  QD  GS  BS  BUS_AREA  VM  VA  BASE_KV  ZONE  VMAX  \
# 1      1         3    0   0   0   0         1   1   0      345     1   1.1
# 2      2         2    0   0   0   0         1   1   0      345     1   1.1
# 3      3         2    0   0   0   0         1   1   0      345     1   1.1
# 4      4         1    0   0   0   0         1   1   0      345     1   1.1
# 5      5         1   90  30   0   0         1   1   0      345     1   1.1
# 6      6         1    0   0   0   0         1   1   0      345     1   1.1
# 7      7         1  100  35   0   0         1   1   0      345     1   1.1
# 8      8         1    0   0   0   0         1   1   0      345     1   1.1
# 9      9         1  125  50   0   0         1   1   0      345     1   1.1
#
#    VMIN
# 1   0.9
# 2   0.9
# 3   0.9
# 4   0.9
# 5   0.9
# 6   0.9
# 7   0.9
# 8   0.9
# 9   0.9

# %%
cf_pu = cf.to_pu()
cf_pu.bus
# Out:
#    BUS_I  BUS_TYPE    PD    QD   GS   BS  BUS_AREA  VM   VA  BASE_KV  ZONE  \
# 1      1         3  0.00  0.00  0.0  0.0         1   1  0.0      345     1
# 2      2         2  0.00  0.00  0.0  0.0         1   1  0.0      345     1
# 3      3         2  0.00  0.00  0.0  0.0         1   1  0.0      345     1
# 4      4         1  0.00  0.00  0.0  0.0         1   1  0.0      345     1
# 5      5         1  0.90  0.30  0.0  0.0         1   1  0.0      345     1
# 6      6         1  0.00  0.00  0.0  0.0         1   1  0.0      345     1
# 7      7         1  1.00  0.35  0.0  0.0         1   1  0.0      345     1
# 8      8         1  0.00  0.00  0.0  0.0         1   1  0.0      345     1
# 9      9         1  1.25  0.50  0.0  0.0         1   1  0.0      345     1
#
#    VMAX  VMIN
# 1   1.1   0.9
# 2   1.1   0.9
# 3   1.1   0.9
# 4   1.1   0.9
# 5   1.1   0.9
# 6   1.1   0.9
# 7   1.1   0.9
# 8   1.1   0.9
# 9   1.1   0.9
